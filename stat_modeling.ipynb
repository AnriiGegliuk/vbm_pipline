# %%
# %load_ext autoreload
# %autoreload 2
import os
from modalities.statistical_modeling_t_test_model import create_two_sample_t_test_model
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# contrasts_name = 'example_contrast'
# contrast1_input_path_list = ['path/to/contrast1/file1.nii', 'path/to/contrast1/file2.nii']
# contrast2_input_path_list = ['path/to/contrast2/file1.nii', 'path/to/contrast2/file2.nii']
# smoothing_dir_path = 'path/to/smoothing_dir'
# # brain_volume_dir_path = 'path/to/brain_volume_dir'  # Not used for now
# model_dir_path = 'path/to/model_dir'

# output_files = create_two_sample_t_test_model(contrasts_name, contrast1_input_path_list,
#                                               contrast2_input_path_list, smoothing_dir_path,
#                                               #brain_volume_dir_path,
#                                               model_dir_path)

# print(output_files)

# %%
contrasts_name = 'example_contrast'
smoothing_dir_path = 'data/analysis_/control_analysis/Dartel/output'  # Base path to smoothed files
model_dir_path = 'data/analysis_/control_analysis/Dartel/output/model_dir'

output_files = create_two_sample_t_test_model(contrasts_name, smoothing_dir_path, model_dir_path)

print(output_files)
# Out:
# 240709-12:04:49,985 nipype.workflow INFO:
# 	 Workflow vbm_stats_modeling settings: ['check', 'execution', 'logging', 'monitoring']
# 240709-12:04:49,991 nipype.workflow INFO:
# 	 Running serially.
# 240709-12:04:49,991 nipype.workflow INFO:
# 	 [Node] Setting-up "vbm_stats_modeling.vbm_stats_modeling" in "/tmp/tmpw_9_lksu/vbm_stats_modeling/vbm_stats_modeling".
# 240709-12:04:49,995 nipype.workflow INFO:
# 	 [Node] Executing "vbm_stats_modeling" <nipype.interfaces.spm.model.TwoSampleTTestDesign>
# stty: 'standard input': Inappropriate ioctl for device
# 240709-12:05:01,239 nipype.workflow INFO:
# 	 [Node] Finished "vbm_stats_modeling", elapsed time 11.242603s.
# 240709-12:05:01,240 nipype.workflow WARNING:
# 	 Storing result file without outputs
# 240709-12:05:01,241 nipype.workflow WARNING:
# 	 [Node] Error on "vbm_stats_modeling.vbm_stats_modeling" (/tmp/tmpw_9_lksu/vbm_stats_modeling/vbm_stats_modeling)
# 240709-12:05:01,244 nipype.workflow ERROR:
# ...
